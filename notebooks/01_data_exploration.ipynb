# %% [markdown]
# # 01 - Data Exploration
#
# Week 1. Before I build anything on top of the corpus I want to be sure it's actually clean.
#
# things to check:
# - load the parsed sections (`data/processed/sections.jsonl`) for BNS / BNSS / BSA
# - do my parsed section counts match the published totals? (`parse_pdf.verify_section_counts`)
# - look at the chunk length distribution from Chonkie, flag anything way too big or too small
# - how much of the IPC to BNS mapping actually resolves? want to know coverage before relying on it
# - read a few sections all the way through (raw PDF to RawSection to LegalChunk) to catch structural noise

# %%
# week 1: fill in once ingestion is implemented
# from src.ingest.parse_pdf import parse_statute, verify_section_counts
# from src.ingest.chunk_chonkie import chunk_sections
